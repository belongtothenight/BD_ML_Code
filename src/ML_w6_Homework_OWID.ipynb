# %% [markdown]
# # Homework
# -------
# 1. Complete the codes just like what I did in the video.
# - Add Logistic regression model and run the codes.  You should analyze bias just like what we have already done with other 4 models.
# - Use different dataset to do the analysis.  Ideal dataset should be a binary classification.  Kaggle.com is a good website to look for the dataset.

# %%
import pandas as pd
import numpy as np
from os.path import join
from os import system, getcwd

# %% [markdown]
# ## 1. Dataset subroutines

# %%
def get_bcw() :
    bcw = pd.read_csv(join(getcwd().rstrip('src'), 'data/wdbc.data').replace('\\', '/') , header=None)
    column_names = ['id','malignant',
                'nucleus_mean','nucleus_se','nucleus_worst',
                'texture_mean','texture_se','texture_worst',
                'perimeter_mean','perimeter_se','perimeter_worst',
                'area_mean','area_se','area_worst',
                'smoothness_mean','smoothness_se','smoothness_worst',
                'compactness_mean','compactness_se','compactness_worst',
                'concavity_mean','concavity_se','concavity_worst',
                'concave_pts_mean','concave_pts_se','concave_pts_worst',
                'symmetry_mean','symmetry_se','symmetry_worst',
                'fractal_dim_mean','fractal_dim_se','fractal_dim_worst']

    bcw.columns = column_names
    
    bcw['malignant'] = bcw['malignant'].map(lambda x: 0 if x == "B" else 1)

    # make a copy for two purposes:
    # 1. keep the original data intake for futural reference.
    # 2. use the same dataset name "mydata" for later processing
    # so that we use the same code for different dataset.

    #     X = mydata[['nucleus_mean','texture_mean','perimeter_mean']]
    X = bcw.drop(columns=['id', 'malignant']).values

    from sklearn.preprocessing import StandardScaler
    ss = StandardScaler()
    X = ss.fit_transform(X)
    
    
    y = bcw['malignant'].values
    return X, y

# %% [markdown]
# # 2. get dataset

# %%
X, y = get_bcw()   # X: feature vector, y label

# %%
X_orig = X
y_orig = y

bcw = pd.DataFrame(X)
bcw.columns = [
                'nucleus_mean','nucleus_se','nucleus_worst',
                'texture_mean','texture_se','texture_worst',
                'perimeter_mean','perimeter_se','perimeter_worst',
                'area_mean','area_se','area_worst',
                'smoothness_mean','smoothness_se','smoothness_worst',
                'compactness_mean','compactness_se','compactness_worst',
                'concavity_mean','concavity_se','concavity_worst',
                'concave_pts_mean','concave_pts_se','concave_pts_worst',
                'symmetry_mean','symmetry_se','symmetry_worst',
                'fractal_dim_mean','fractal_dim_se','fractal_dim_worst']
bcw['malignant'] = y

bcw.head()
# Out:
#    nucleus_mean  nucleus_se  nucleus_worst  texture_mean  texture_se  \
# 0      1.097064   -2.073335       1.269934      0.984375    1.568466
# 1      1.829821   -0.353632       1.685955      1.908708   -0.826962
# 2      1.579888    0.456187       1.566503      1.558884    0.942210
# 3     -0.768909    0.253732      -0.592687     -0.764464    3.283553
# 4      1.750297   -1.151816       1.776573      1.826229    0.280372
#
#    texture_worst  perimeter_mean  perimeter_se  perimeter_worst  area_mean  \
# 0       3.283515        2.652874      2.532475         2.217515   2.255747
# 1      -0.487072       -0.023846      0.548144         0.001392  -0.868652
# 2       1.052926        1.363478      2.037231         0.939685  -0.398008
# 3       3.402909        1.915897      1.451707         2.867383   4.910919
# 4       0.539340        1.371011      1.428493        -0.009560  -0.562450
#
#    ...  concave_pts_mean  concave_pts_se  concave_pts_worst  symmetry_mean  \
# 0  ...         -1.359293        2.303601           2.001237       1.307686
# 1  ...         -0.369203        1.535126           1.890489      -0.375612
# 2  ...         -0.023974        1.347475           1.456285       0.527407
# 3  ...          0.133984       -0.249939          -0.550021       3.394275
# 4  ...         -1.466770        1.338539           1.220724       0.220556
#
#    symmetry_se  symmetry_worst  fractal_dim_mean  fractal_dim_se  \
# 0     2.616665        2.109526          2.296076        2.750622
# 1    -0.430444       -0.146749          1.087084       -0.243890
# 2     1.082932        0.854974          1.955000        1.152255
# 3     3.893397        1.989588          2.175786        6.046041
# 4    -0.313395        0.613179          0.729259       -0.868353
#
#    fractal_dim_worst  malignant
# 0           1.937015          1
# 1           0.281190          1
# 2           0.201391          1
# 3           4.935010          1
# 4          -0.397100          1
#
# [5 rows x 31 columns]

# %%
cols = bcw.columns
['malignant'] + list(cols[:-1])
# Out:
# ['malignant',
#  'nucleus_mean',
#  'nucleus_se',
#  'nucleus_worst',
#  'texture_mean',
#  'texture_se',
#  'texture_worst',
#  'perimeter_mean',
#  'perimeter_se',
#  'perimeter_worst',
#  'area_mean',
#  'area_se',
#  'area_worst',
#  'smoothness_mean',
#  'smoothness_se',
#  'smoothness_worst',
#  'compactness_mean',
#  'compactness_se',
#  'compactness_worst',
#  'concavity_mean',
#  'concavity_se',
#  'concavity_worst',
#  'concave_pts_mean',
#  'concave_pts_se',
#  'concave_pts_worst',
#  'symmetry_mean',
#  'symmetry_se',
#  'symmetry_worst',
#  'fractal_dim_mean',
#  'fractal_dim_se',
#  'fractal_dim_worst']

# %%
# try to move 'malignant' column to the front.
cols = bcw.columns
# print(['malignant'] + list(cols[:-1]))
bcw = bcw[['malignant'] + list(cols[:-1])]
bcw.head()
# Out:
#    malignant  nucleus_mean  nucleus_se  nucleus_worst  texture_mean  \
# 0          1      1.097064   -2.073335       1.269934      0.984375
# 1          1      1.829821   -0.353632       1.685955      1.908708
# 2          1      1.579888    0.456187       1.566503      1.558884
# 3          1     -0.768909    0.253732      -0.592687     -0.764464
# 4          1      1.750297   -1.151816       1.776573      1.826229
#
#    texture_se  texture_worst  perimeter_mean  perimeter_se  perimeter_worst  \
# 0    1.568466       3.283515        2.652874      2.532475         2.217515
# 1   -0.826962      -0.487072       -0.023846      0.548144         0.001392
# 2    0.942210       1.052926        1.363478      2.037231         0.939685
# 3    3.283553       3.402909        1.915897      1.451707         2.867383
# 4    0.280372       0.539340        1.371011      1.428493        -0.009560
#
#    ...  concavity_worst  concave_pts_mean  concave_pts_se  concave_pts_worst  \
# 0  ...         1.886690         -1.359293        2.303601           2.001237
# 1  ...         1.805927         -0.369203        1.535126           1.890489
# 2  ...         1.511870         -0.023974        1.347475           1.456285
# 3  ...        -0.281464          0.133984       -0.249939          -0.550021
# 4  ...         1.298575         -1.466770        1.338539           1.220724
#
#    symmetry_mean  symmetry_se  symmetry_worst  fractal_dim_mean  \
# 0       1.307686     2.616665        2.109526          2.296076
# 1      -0.375612    -0.430444       -0.146749          1.087084
# 2       0.527407     1.082932        0.854974          1.955000
# 3       3.394275     3.893397        1.989588          2.175786
# 4       0.220556    -0.313395        0.613179          0.729259
#
#    fractal_dim_se  fractal_dim_worst
# 0        2.750622           1.937015
# 1       -0.243890           0.281190
# 2        1.152255           0.201391
# 3        6.046041           4.935010
# 4       -0.868353          -0.397100
#
# [5 rows x 31 columns]

# %%
def GetImbalancedLabelData(DF_orig, label_ratio) :
    import copy as copy
    from sklearn.model_selection import train_test_split
    DF = copy.copy(DF_orig)
    DF1 = DF[DF.malignant == 1]
    DF0 = DF[DF.malignant == 0]
    
    Test_Size= 0.25
    max_train0_size = min(DF0.shape[0], DF1.shape[0])
    TestSizeFrom0 =1 -  min(max_train0_size, DF0.shape[0] * (1- Test_Size) ) / DF0.shape[0]
    
    
    DF0_train, DF0_test = train_test_split(DF0, test_size = TestSizeFrom0, random_state=2018)
    
    DF1_train, DF1_test = train_test_split(DF1, test_size =  (1 - label_ratio), random_state=2018)
    
    DF_train = pd.concat((DF0_train, DF1_train) )
    DF_test = pd.concat((DF0_test, DF1_test) )
    
    y_train = DF_train.malignant.values
    X_train = DF_train.drop(columns=[ 'malignant']).values
    y_test = DF_test.malignant.values
    X_test = DF_test.drop(columns=[ 'malignant']).values

    return X_train, X_test, y_train, y_test

# %%
X_train, X_test, y_train, y_test = GetImbalancedLabelData(bcw, 0.1)

# %% [markdown]
# # 3. Split Data into Training and Testing
# --------
# Choose 3.1  and 3.2 to get the type of split data you want to train.

# %% [markdown]
# # 3.1 Original Data Split

# %%
from sklearn.model_selection import train_test_split

print(X.shape)
print(y.shape)
print(type(X))
print(type(y))
# numpy array does not have column names.  
# We can only use the slice [row_start:row_end:step_row, col_start:col_end:step_col]
# to select rows and cols we want
# be aware that row_end and col_end are not inclusive
# the format of the output will be discussed in another lecture.
print(X[0:6:2])
print(y[0:40:4])

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state=2018)
# Out:
# (569, 30)
# (569,)
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# [[ 1.09706398 -2.07333501  1.26993369  0.9843749   1.56846633  3.28351467
#    2.65287398  2.53247522  2.21751501  2.25574689  2.48973393 -0.56526506
#    2.83303087  2.48757756 -0.21400165  1.31686157  0.72402616  0.66081994
#    1.14875667  0.90708308  1.88668963 -1.35929347  2.30360062  2.00123749
#    1.30768627  2.61666502  2.10952635  2.29607613  2.75062224  1.93701461]
#  [ 1.57988811  0.45618695  1.56650313  1.55888363  0.94221044  1.05292554
#    1.36347845  2.03723076  0.93968482 -0.39800791  1.22867595 -0.78008338
#    0.8509283   1.18133606 -0.29700501  0.8149735   0.21307643  1.42482747
#    0.23703554  0.2935594   1.51187025 -0.02397438  1.34747521  1.45628455
#    0.52740741  1.08293217  0.85497394  1.95500035  1.152255    0.20139121]
#  [ 1.75029663 -1.15181643  1.77657315  1.82622928  0.28037183  0.53934045
#    1.37101143  1.42849277 -0.00956047 -0.56244998  1.27054278 -0.7902437
#    1.27318941  1.19035676  1.48306716 -0.04851988  0.82847078  1.14420474
#   -0.36109227  0.49932813  1.29857524 -1.46677038  1.33853946  1.22072425
#    0.22055617 -0.31339451  0.61317876  0.72925926 -0.86835298 -0.39709962]]
# [1 1 1 1 1 0 1 1 1 1]

# %% [markdown]
# # 3.2 Data Split to Get Imbalanced Labels in Training Data

# %%
def GetImbalancedLabelData(DF_orig, label_ratio) :
    import copy as copy
    from sklearn.model_selection import train_test_split
    DF = copy.copy(DF_orig)
    DF1 = DF[DF.malignant == 1]
    DF0 = DF[DF.malignant == 0]
    
    Test_Size= 0.25  # intended test size.  The actual size depend on how the train data is arranged.
    # Simple implementation : 
    #      split both DF0 with Test_Size and DF1 with label_ratio 
    #      This method can not produce the right label_ratio for training set. 
#     TestSizeFrom0 =  Test_Size
    # instead , the following 2 statement, can split the training data in the precise label_ratio.
    max_train0_size = min(DF0.shape[0], DF1.shape[0])  
    TestSizeFrom0 = 1 -  min(max_train0_size, DF0.shape[0] * (1- Test_Size) ) / DF0.shape[0]
    
    
    DF0_train, DF0_test = train_test_split(DF0, test_size = TestSizeFrom0, random_state=2018)
    DF1_train, DF1_test = train_test_split(DF1, test_size =  (1 - label_ratio), random_state=2018)
    
    DF_train = pd.concat((DF0_train, DF1_train) )
    DF_test = pd.concat((DF0_test, DF1_test) )
    
    y_train = DF_train.malignant.values
    X_train = DF_train.drop(columns=[ 'malignant']).values
    y_test = DF_test.malignant.values
    X_test = DF_test.drop(columns=[ 'malignant']).values

    return X_train, X_test, y_train, y_test

# %%
X_train, X_test, y_train, y_test = GetImbalancedLabelData(bcw, 0.5)
print(y_train.sum(), y_train.shape,  y_test.sum(), y_test.shape,)
print(y_train.sum()/( y_train.shape[0] - y_train.sum() )  )
# Out:
# 106 (318,) 106 (251,)
# 0.5

# %% [markdown]
# # 4. Build ML/DL model (model specific)

# %%
def evaluate(pred, expect) :
    ans = pred - expect
    error_sum = ans.sum()
    n_errors = abs(ans).sum()
    accuracy = 1 - n_errors / expect.shape[0]
    
    return round(accuracy, 3) , n_errors, error_sum

# %%
def RunAllModels(bcw, Label_Ratio, default=True):
    X_train, X_test, y_train, y_test = GetImbalancedLabelData(bcw, 0.5)
    Result = []
    
    from sklearn.tree import DecisionTreeClassifier
    if default:
        model = DecisionTreeClassifier()
    else:
        model = DecisionTreeClassifier(class_weight='balanced')
    model.fit(X_train, y_train)
    pred = model.predict(X_test)
    Result.append(['DT', default, round(Label_Ratio, 2)] + list(evaluate(pred, y_test)))

    from sklearn.ensemble import RandomForestClassifier
    if default:
        model = RandomForestClassifier(n_estimators=100)
    else:
        model = RandomForestClassifier(n_estimators=100, class_weight='balanced')
    model.fit(X_train, y_train)
    pred = model.predict(X_test)
    Result.append(['RF', default, round(Label_Ratio, 2)] + list(evaluate(pred, y_test)))

    from sklearn.neighbors import KNeighborsClassifier
    if default:
        model = KNeighborsClassifier()
    else:
        model = KNeighborsClassifier(weights='distance')
    model.fit(X_train, y_train)
    pred = model.predict(X_test)
    Result.append(['KNN', default, round(Label_Ratio, 2)] + list(evaluate(pred, y_test)))

    from sklearn.svm import SVC
    if default:
        model = SVC()
    else:
        # # model = SVC(gamma='scale')
        model = SVC(gamma='scale', class_weight='balanced')
    model.fit(X_train, y_train)
    pred = model.predict(X_test)
    Result.append(['SVC', default, round(Label_Ratio, 2)] + list(evaluate(pred, y_test)))
    
    from sklearn.linear_model import LogisticRegression
    if default:
        model = LogisticRegression()
    else:
        model = LogisticRegression(class_weight='balanced')
    model.fit(X_train, y_train)
    pred = model.predict(X_test)
    Result.append(['LR', default, round(Label_Ratio, 2)] + list(evaluate(pred, y_test)))
    
    return Result

# %%
Default = []
for i in range(10, 100):
    labelratio = 0.01 * i
    Default += RunAllModels(bcw, labelratio)
Default
# Out:
# [['DT', True, 0.1, 0.936, 16, -6],
#  ['RF', True, 0.1, 0.932, 17, -9],
#  ['KNN', True, 0.1, 0.952, 12, -12],
#  ['SVC', True, 0.1, 0.96, 10, -6],
#  ['LR', True, 0.1, 0.96, 10, -8],
#  ['DT', True, 0.11, 0.932, 17, -5],
#  ['RF', True, 0.11, 0.94, 15, -9],
#  ['KNN', True, 0.11, 0.952, 12, -12],
#  ['SVC', True, 0.11, 0.96, 10, -6],
#  ['LR', True, 0.11, 0.96, 10, -8],
#  ['DT', True, 0.12, 0.92, 20, -6],
#  ['RF', True, 0.12, 0.936, 16, -10],
#  ['KNN', True, 0.12, 0.952, 12, -12],
#  ['SVC', True, 0.12, 0.96, 10, -6],
#  ['LR', True, 0.12, 0.96, 10, -8],
#  ['DT', True, 0.13, 0.924, 19, -5],
#  ['RF', True, 0.13, 0.932, 17, -7],
#  ['KNN', True, 0.13, 0.952, 12, -12],
#  ['SVC', True, 0.13, 0.96, 10, -6],
#  ['LR', True, 0.13, 0.96, 10, -8],
#  ['DT', True, 0.14, 0.924, 19, -7],
#  ['RF', True, 0.14, 0.936, 16, -8],
#  ['KNN', True, 0.14, 0.952, 12, -12],
#  ['SVC', True, 0.14, 0.96, 10, -6],
#  ['LR', True, 0.14, 0.96, 10, -8],
#  ['DT', True, 0.15, 0.924, 19, -5],
#  ['RF', True, 0.15, 0.932, 17, -9],
#  ['KNN', True, 0.15, 0.952, 12, -12],
#  ['SVC', True, 0.15, 0.96, 10, -6],
#  ['LR', True, 0.15, 0.96, 10, -8],
#  ['DT', True, 0.16, 0.932, 17, -7],
#  ['RF', True, 0.16, 0.936, 16, -8],
#  ['KNN', True, 0.16, 0.952, 12, -12],
#  ['SVC', True, 0.16, 0.96, 10, -6],
#  ['LR', True, 0.16, 0.96, 10, -8],
#  ['DT', True, 0.17, 0.924, 19, -5],
#  ['RF', True, 0.17, 0.936, 16, -8],
#  ['KNN', True, 0.17, 0.952, 12, -12],
#  ['SVC', True, 0.17, 0.96, 10, -6],
#  ['LR', True, 0.17, 0.96, 10, -8],
#  ['DT', True, 0.18, 0.92, 20, -6],
#  ['RF', True, 0.18, 0.94, 15, -7],
#  ['KNN', True, 0.18, 0.952, 12, -12],
#  ['SVC', True, 0.18, 0.96, 10, -6],
#  ['LR', True, 0.18, 0.96, 10, -8],
#  ['DT', True, 0.19, 0.924, 19, -5],
#  ['RF', True, 0.19, 0.94, 15, -9],
#  ['KNN', True, 0.19, 0.952, 12, -12],
#  ['SVC', True, 0.19, 0.96, 10, -6],
#  ['LR', True, 0.19, 0.96, 10, -8],
#  ['DT', True, 0.2, 0.932, 17, -5],
#  ['RF', True, 0.2, 0.936, 16, -8],
#  ['KNN', True, 0.2, 0.952, 12, -12],
#  ['SVC', True, 0.2, 0.96, 10, -6],
#  ['LR', True, 0.2, 0.96, 10, -8],
#  ['DT', True, 0.21, 0.936, 16, -6],
#  ['RF', True, 0.21, 0.932, 17, -9],
#  ['KNN', True, 0.21, 0.952, 12, -12],
#  ['SVC', True, 0.21, 0.96, 10, -6],
#  ['LR', True, 0.21, 0.96, 10, -8],
#  ['DT', True, 0.22, 0.924, 19, -5],
#  ['RF', True, 0.22, 0.936, 16, -8],
#  ['KNN', True, 0.22, 0.952, 12, -12],
#  ['SVC', True, 0.22, 0.96, 10, -6],
#  ['LR', True, 0.22, 0.96, 10, -8],
#  ['DT', True, 0.23, 0.928, 18, -6],
#  ['RF', True, 0.23, 0.944, 14, -8],
#  ['KNN', True, 0.23, 0.952, 12, -12],
#  ['SVC', True, 0.23, 0.96, 10, -6],
#  ['LR', True, 0.23, 0.96, 10, -8],
#  ['DT', True, 0.24, 0.936, 16, -6],
#  ['RF', True, 0.24, 0.936, 16, -10],
#  ['KNN', True, 0.24, 0.952, 12, -12],
#  ['SVC', True, 0.24, 0.96, 10, -6],
#  ['LR', True, 0.24, 0.96, 10, -8],
#  ['DT', True, 0.25, 0.936, 16, -6],
#  ['RF', True, 0.25, 0.936, 16, -10],
#  ['KNN', True, 0.25, 0.952, 12, -12],
#  ['SVC', True, 0.25, 0.96, 10, -6],
#  ['LR', True, 0.25, 0.96, 10, -8],
#  ['DT', True, 0.26, 0.92, 20, -4],
#  ['RF', True, 0.26, 0.928, 18, -8],
#  ['KNN', True, 0.26, 0.952, 12, -12],
#  ['SVC', True, 0.26, 0.96, 10, -6],
#  ['LR', True, 0.26, 0.96, 10, -8],
#  ['DT', True, 0.27, 0.924, 19, -3],
#  ['RF', True, 0.27, 0.936, 16, -6],
#  ['KNN', True, 0.27, 0.952, 12, -12],
#  ['SVC', True, 0.27, 0.96, 10, -6],
#  ['LR', True, 0.27, 0.96, 10, -8],
#  ['DT', True, 0.28, 0.932, 17, -5],
#  ['RF', True, 0.28, 0.928, 18, -8],
#  ['KNN', True, 0.28, 0.952, 12, -12],
#  ['SVC', True, 0.28, 0.96, 10, -6],
#  ['LR', True, 0.28, 0.96, 10, -8],
#  ['DT', True, 0.29, 0.932, 17, -5],
#  ['RF', True, 0.29, 0.932, 17, -7],
#  ['KNN', True, 0.29, 0.952, 12, -12],
#  ['SVC', True, 0.29, 0.96, 10, -6],
#  ['LR', True, 0.29, 0.96, 10, -8],
#  ['DT', True, 0.3, 0.928, 18, -8],
#  ['RF', True, 0.3, 0.936, 16, -8],
#  ['KNN', True, 0.3, 0.952, 12, -12],
#  ['SVC', True, 0.3, 0.96, 10, -6],
#  ['LR', True, 0.3, 0.96, 10, -8],
#  ['DT', True, 0.31, 0.932, 17, -7],
#  ['RF', True, 0.31, 0.936, 16, -8],
#  ['KNN', True, 0.31, 0.952, 12, -12],
#  ['SVC', True, 0.31, 0.96, 10, -6],
#  ['LR', True, 0.31, 0.96, 10, -8],
#  ['DT', True, 0.32, 0.92, 20, -4],
#  ['RF', True, 0.32, 0.94, 15, -7],
#  ['KNN', True, 0.32, 0.952, 12, -12],
#  ['SVC', True, 0.32, 0.96, 10, -6],
#  ['LR', True, 0.32, 0.96, 10, -8],
#  ['DT', True, 0.33, 0.928, 18, -6],
#  ['RF', True, 0.33, 0.932, 17, -9],
#  ['KNN', True, 0.33, 0.952, 12, -12],
#  ['SVC', True, 0.33, 0.96, 10, -6],
#  ['LR', True, 0.33, 0.96, 10, -8],
#  ['DT', True, 0.34, 0.932, 17, -7],
#  ['RF', True, 0.34, 0.936, 16, -8],
#  ['KNN', True, 0.34, 0.952, 12, -12],
#  ['SVC', True, 0.34, 0.96, 10, -6],
#  ['LR', True, 0.34, 0.96, 10, -8],
#  ['DT', True, 0.35, 0.928, 18, -6],
#  ['RF', True, 0.35, 0.936, 16, -10],
#  ['KNN', True, 0.35, 0.952, 12, -12],
#  ['SVC', True, 0.35, 0.96, 10, -6],
#  ['LR', True, 0.35, 0.96, 10, -8],
#  ['DT', True, 0.36, 0.928, 18, -6],
#  ['RF', True, 0.36, 0.94, 15, -5],
#  ['KNN', True, 0.36, 0.952, 12, -12],
#  ['SVC', True, 0.36, 0.96, 10, -6],
#  ['LR', True, 0.36, 0.96, 10, -8],
#  ['DT', True, 0.37, 0.928, 18, -6],
#  ['RF', True, 0.37, 0.944, 14, -10],
#  ['KNN', True, 0.37, 0.952, 12, -12],
#  ['SVC', True, 0.37, 0.96, 10, -6],
#  ['LR', True, 0.37, 0.96, 10, -8],
#  ['DT', True, 0.38, 0.924, 19, -5],
#  ['RF', True, 0.38, 0.94, 15, -9],
#  ['KNN', True, 0.38, 0.952, 12, -12],
#  ['SVC', True, 0.38, 0.96, 10, -6],
#  ['LR', True, 0.38, 0.96, 10, -8],
#  ['DT', True, 0.39, 0.936, 16, -6],
#  ['RF', True, 0.39, 0.936, 16, -8],
#  ['KNN', True, 0.39, 0.952, 12, -12],
#  ['SVC', True, 0.39, 0.96, 10, -6],
#  ['LR', True, 0.39, 0.96, 10, -8],
#  ['DT', True, 0.4, 0.92, 20, -6],
#  ['RF', True, 0.4, 0.94, 15, -7],
#  ['KNN', True, 0.4, 0.952, 12, -12],
#  ['SVC', True, 0.4, 0.96, 10, -6],
#  ['LR', True, 0.4, 0.96, 10, -8],
#  ['DT', True, 0.41, 0.928, 18, -6],
#  ['RF', True, 0.41, 0.936, 16, -10],
#  ['KNN', True, 0.41, 0.952, 12, -12],
#  ['SVC', True, 0.41, 0.96, 10, -6],
#  ['LR', True, 0.41, 0.96, 10, -8],
#  ['DT', True, 0.42, 0.928, 18, -6],
#  ['RF', True, 0.42, 0.936, 16, -10],
#  ['KNN', True, 0.42, 0.952, 12, -12],
#  ['SVC', True, 0.42, 0.96, 10, -6],
#  ['LR', True, 0.42, 0.96, 10, -8],
#  ['DT', True, 0.43, 0.928, 18, -4],
#  ['RF', True, 0.43, 0.944, 14, -10],
#  ['KNN', True, 0.43, 0.952, 12, -12],
#  ['SVC', True, 0.43, 0.96, 10, -6],
#  ['LR', True, 0.43, 0.96, 10, -8],
#  ['DT', True, 0.44, 0.92, 20, -6],
#  ['RF', True, 0.44, 0.936, 16, -8],
#  ['KNN', True, 0.44, 0.952, 12, -12],
#  ['SVC', True, 0.44, 0.96, 10, -6],
#  ['LR', True, 0.44, 0.96, 10, -8],
#  ['DT', True, 0.45, 0.936, 16, -8],
#  ['RF', True, 0.45, 0.94, 15, -5],
#  ['KNN', True, 0.45, 0.952, 12, -12],
#  ['SVC', True, 0.45, 0.96, 10, -6],
#  ['LR', True, 0.45, 0.96, 10, -8],
#  ['DT', True, 0.46, 0.924, 19, -5],
#  ['RF', True, 0.46, 0.932, 17, -9],
#  ['KNN', True, 0.46, 0.952, 12, -12],
#  ['SVC', True, 0.46, 0.96, 10, -6],
#  ['LR', True, 0.46, 0.96, 10, -8],
#  ['DT', True, 0.47, 0.936, 16, -6],
#  ['RF', True, 0.47, 0.944, 14, -10],
#  ['KNN', True, 0.47, 0.952, 12, -12],
#  ['SVC', True, 0.47, 0.96, 10, -6],
#  ['LR', True, 0.47, 0.96, 10, -8],
#  ['DT', True, 0.48, 0.932, 17, -5],
#  ['RF', True, 0.48, 0.928, 18, -8],
#  ['KNN', True, 0.48, 0.952, 12, -12],
#  ['SVC', True, 0.48, 0.96, 10, -6],
#  ['LR', True, 0.48, 0.96, 10, -8],
#  ['DT', True, 0.49, 0.924, 19, -7],
#  ['RF', True, 0.49, 0.932, 17, -7],
#  ['KNN', True, 0.49, 0.952, 12, -12],
#  ['SVC', True, 0.49, 0.96, 10, -6],
#  ['LR', True, 0.49, 0.96, 10, -8],
#  ['DT', True, 0.5, 0.932, 17, -5],
#  ['RF', True, 0.5, 0.932, 17, -7],
#  ['KNN', True, 0.5, 0.952, 12, -12],
#  ['SVC', True, 0.5, 0.96, 10, -6],
#  ['LR', True, 0.5, 0.96, 10, -8],
#  ['DT', True, 0.51, 0.928, 18, -6],
#  ['RF', True, 0.51, 0.94, 15, -9],
#  ['KNN', True, 0.51, 0.952, 12, -12],
#  ['SVC', True, 0.51, 0.96, 10, -6],
#  ['LR', True, 0.51, 0.96, 10, -8],
#  ['DT', True, 0.52, 0.936, 16, -8],
#  ['RF', True, 0.52, 0.936, 16, -6],
#  ['KNN', True, 0.52, 0.952, 12, -12],
#  ['SVC', True, 0.52, 0.96, 10, -6],
#  ['LR', True, 0.52, 0.96, 10, -8],
#  ['DT', True, 0.53, 0.924, 19, -3],
#  ['RF', True, 0.53, 0.932, 17, -7],
#  ['KNN', True, 0.53, 0.952, 12, -12],
#  ['SVC', True, 0.53, 0.96, 10, -6],
#  ['LR', True, 0.53, 0.96, 10, -8],
#  ['DT', True, 0.54, 0.924, 19, -5],
#  ['RF', True, 0.54, 0.94, 15, -9],
#  ['KNN', True, 0.54, 0.952, 12, -12],
#  ['SVC', True, 0.54, 0.96, 10, -6],
#  ['LR', True, 0.54, 0.96, 10, -8],
#  ['DT', True, 0.55, 0.924, 19, -3],
#  ['RF', True, 0.55, 0.936, 16, -8],
#  ['KNN', True, 0.55, 0.952, 12, -12],
#  ['SVC', True, 0.55, 0.96, 10, -6],
#  ['LR', True, 0.55, 0.96, 10, -8],
#  ['DT', True, 0.56, 0.928, 18, -6],
#  ['RF', True, 0.56, 0.94, 15, -9],
#  ['KNN', True, 0.56, 0.952, 12, -12],
#  ['SVC', True, 0.56, 0.96, 10, -6],
#  ['LR', True, 0.56, 0.96, 10, -8],
#  ['DT', True, 0.57, 0.936, 16, -6],
#  ['RF', True, 0.57, 0.94, 15, -9],
#  ['KNN', True, 0.57, 0.952, 12, -12],
#  ['SVC', True, 0.57, 0.96, 10, -6],
#  ['LR', True, 0.57, 0.96, 10, -8],
#  ['DT', True, 0.58, 0.92, 20, -4],
#  ['RF', True, 0.58, 0.94, 15, -11],
#  ['KNN', True, 0.58, 0.952, 12, -12],
#  ['SVC', True, 0.58, 0.96, 10, -6],
#  ['LR', True, 0.58, 0.96, 10, -8],
#  ['DT', True, 0.59, 0.924, 19, -5],
#  ['RF', True, 0.59, 0.94, 15, -5],
#  ['KNN', True, 0.59, 0.952, 12, -12],
#  ['SVC', True, 0.59, 0.96, 10, -6],
#  ['LR', True, 0.59, 0.96, 10, -8],
#  ['DT', True, 0.6, 0.928, 18, -4],
#  ['RF', True, 0.6, 0.944, 14, -8],
#  ['KNN', True, 0.6, 0.952, 12, -12],
#  ['SVC', True, 0.6, 0.96, 10, -6],
#  ['LR', True, 0.6, 0.96, 10, -8],
#  ['DT', True, 0.61, 0.932, 17, -9],
#  ['RF', True, 0.61, 0.928, 18, -8],
#  ['KNN', True, 0.61, 0.952, 12, -12],
#  ['SVC', True, 0.61, 0.96, 10, -6],
#  ['LR', True, 0.61, 0.96, 10, -8],
#  ['DT', True, 0.62, 0.92, 20, -6],
#  ['RF', True, 0.62, 0.936, 16, -6],
#  ['KNN', True, 0.62, 0.952, 12, -12],
#  ['SVC', True, 0.62, 0.96, 10, -6],
#  ['LR', True, 0.62, 0.96, 10, -8],
#  ['DT', True, 0.63, 0.928, 18, -6],
#  ['RF', True, 0.63, 0.94, 15, -7],
#  ['KNN', True, 0.63, 0.952, 12, -12],
#  ['SVC', True, 0.63, 0.96, 10, -6],
#  ['LR', True, 0.63, 0.96, 10, -8],
#  ['DT', True, 0.64, 0.932, 17, -5],
#  ['RF', True, 0.64, 0.932, 17, -9],
#  ['KNN', True, 0.64, 0.952, 12, -12],
#  ['SVC', True, 0.64, 0.96, 10, -6],
#  ['LR', True, 0.64, 0.96, 10, -8],
#  ['DT', True, 0.65, 0.928, 18, -6],
#  ['RF', True, 0.65, 0.944, 14, -10],
#  ['KNN', True, 0.65, 0.952, 12, -12],
#  ['SVC', True, 0.65, 0.96, 10, -6],
#  ['LR', True, 0.65, 0.96, 10, -8],
#  ['DT', True, 0.66, 0.936, 16, -8],
#  ['RF', True, 0.66, 0.936, 16, -8],
#  ['KNN', True, 0.66, 0.952, 12, -12],
#  ['SVC', True, 0.66, 0.96, 10, -6],
#  ['LR', True, 0.66, 0.96, 10, -8],
#  ['DT', True, 0.67, 0.936, 16, -6],
#  ['RF', True, 0.67, 0.936, 16, -8],
#  ['KNN', True, 0.67, 0.952, 12, -12],
#  ['SVC', True, 0.67, 0.96, 10, -6],
#  ['LR', True, 0.67, 0.96, 10, -8],
#  ['DT', True, 0.68, 0.928, 18, -8],
#  ['RF', True, 0.68, 0.94, 15, -9],
#  ['KNN', True, 0.68, 0.952, 12, -12],
#  ['SVC', True, 0.68, 0.96, 10, -6],
#  ['LR', True, 0.68, 0.96, 10, -8],
#  ['DT', True, 0.69, 0.936, 16, -6],
#  ['RF', True, 0.69, 0.932, 17, -9],
#  ['KNN', True, 0.69, 0.952, 12, -12],
#  ['SVC', True, 0.69, 0.96, 10, -6],
#  ['LR', True, 0.69, 0.96, 10, -8],
#  ['DT', True, 0.7, 0.924, 19, -9],
#  ['RF', True, 0.7, 0.928, 18, -8],
#  ['KNN', True, 0.7, 0.952, 12, -12],
#  ['SVC', True, 0.7, 0.96, 10, -6],
#  ['LR', True, 0.7, 0.96, 10, -8],
#  ['DT', True, 0.71, 0.928, 18, -6],
#  ['RF', True, 0.71, 0.94, 15, -7],
#  ['KNN', True, 0.71, 0.952, 12, -12],
#  ['SVC', True, 0.71, 0.96, 10, -6],
#  ['LR', True, 0.71, 0.96, 10, -8],
#  ['DT', True, 0.72, 0.932, 17, -5],
#  ['RF', True, 0.72, 0.932, 17, -9],
#  ['KNN', True, 0.72, 0.952, 12, -12],
#  ['SVC', True, 0.72, 0.96, 10, -6],
#  ['LR', True, 0.72, 0.96, 10, -8],
#  ['DT', True, 0.73, 0.932, 17, -5],
#  ['RF', True, 0.73, 0.928, 18, -8],
#  ['KNN', True, 0.73, 0.952, 12, -12],
#  ['SVC', True, 0.73, 0.96, 10, -6],
#  ['LR', True, 0.73, 0.96, 10, -8],
#  ['DT', True, 0.74, 0.932, 17, -5],
#  ['RF', True, 0.74, 0.94, 15, -9],
#  ['KNN', True, 0.74, 0.952, 12, -12],
#  ['SVC', True, 0.74, 0.96, 10, -6],
#  ['LR', True, 0.74, 0.96, 10, -8],
#  ['DT', True, 0.75, 0.932, 17, -5],
#  ['RF', True, 0.75, 0.936, 16, -8],
#  ['KNN', True, 0.75, 0.952, 12, -12],
#  ['SVC', True, 0.75, 0.96, 10, -6],
#  ['LR', True, 0.75, 0.96, 10, -8],
#  ['DT', True, 0.76, 0.936, 16, -6],
#  ['RF', True, 0.76, 0.944, 14, -8],
#  ['KNN', True, 0.76, 0.952, 12, -12],
#  ['SVC', True, 0.76, 0.96, 10, -6],
#  ['LR', True, 0.76, 0.96, 10, -8],
#  ['DT', True, 0.77, 0.928, 18, -6],
#  ['RF', True, 0.77, 0.928, 18, -8],
#  ['KNN', True, 0.77, 0.952, 12, -12],
#  ['SVC', True, 0.77, 0.96, 10, -6],
#  ['LR', True, 0.77, 0.96, 10, -8],
#  ['DT', True, 0.78, 0.924, 19, -5],
#  ['RF', True, 0.78, 0.936, 16, -8],
#  ['KNN', True, 0.78, 0.952, 12, -12],
#  ['SVC', True, 0.78, 0.96, 10, -6],
#  ['LR', True, 0.78, 0.96, 10, -8],
#  ['DT', True, 0.79, 0.928, 18, -6],
#  ['RF', True, 0.79, 0.936, 16, -8],
#  ['KNN', True, 0.79, 0.952, 12, -12],
#  ['SVC', True, 0.79, 0.96, 10, -6],
#  ['LR', True, 0.79, 0.96, 10, -8],
#  ['DT', True, 0.8, 0.92, 20, -6],
#  ['RF', True, 0.8, 0.94, 15, -9],
#  ['KNN', True, 0.8, 0.952, 12, -12],
#  ['SVC', True, 0.8, 0.96, 10, -6],
#  ['LR', True, 0.8, 0.96, 10, -8],
#  ['DT', True, 0.81, 0.924, 19, -7],
#  ['RF', True, 0.81, 0.932, 17, -9],
#  ['KNN', True, 0.81, 0.952, 12, -12],
#  ['SVC', True, 0.81, 0.96, 10, -6],
#  ['LR', True, 0.81, 0.96, 10, -8],
#  ['DT', True, 0.82, 0.932, 17, -5],
#  ['RF', True, 0.82, 0.932, 17, -9],
#  ['KNN', True, 0.82, 0.952, 12, -12],
#  ['SVC', True, 0.82, 0.96, 10, -6],
#  ['LR', True, 0.82, 0.96, 10, -8],
#  ['DT', True, 0.83, 0.932, 17, -7],
#  ['RF', True, 0.83, 0.94, 15, -9],
#  ['KNN', True, 0.83, 0.952, 12, -12],
#  ['SVC', True, 0.83, 0.96, 10, -6],
#  ['LR', True, 0.83, 0.96, 10, -8],
#  ['DT', True, 0.84, 0.932, 17, -5],
#  ['RF', True, 0.84, 0.936, 16, -6],
#  ['KNN', True, 0.84, 0.952, 12, -12],
#  ['SVC', True, 0.84, 0.96, 10, -6],
#  ['LR', True, 0.84, 0.96, 10, -8],
#  ['DT', True, 0.85, 0.92, 20, -6],
#  ['RF', True, 0.85, 0.944, 14, -10],
#  ['KNN', True, 0.85, 0.952, 12, -12],
#  ['SVC', True, 0.85, 0.96, 10, -6],
#  ['LR', True, 0.85, 0.96, 10, -8],
#  ['DT', True, 0.86, 0.932, 17, -5],
#  ['RF', True, 0.86, 0.94, 15, -9],
#  ['KNN', True, 0.86, 0.952, 12, -12],
#  ['SVC', True, 0.86, 0.96, 10, -6],
#  ['LR', True, 0.86, 0.96, 10, -8],
#  ['DT', True, 0.87, 0.928, 18, -6],
#  ['RF', True, 0.87, 0.932, 17, -9],
#  ['KNN', True, 0.87, 0.952, 12, -12],
#  ['SVC', True, 0.87, 0.96, 10, -6],
#  ['LR', True, 0.87, 0.96, 10, -8],
#  ['DT', True, 0.88, 0.928, 18, -4],
#  ['RF', True, 0.88, 0.936, 16, -10],
#  ['KNN', True, 0.88, 0.952, 12, -12],
#  ['SVC', True, 0.88, 0.96, 10, -6],
#  ['LR', True, 0.88, 0.96, 10, -8],
#  ['DT', True, 0.89, 0.924, 19, -5],
#  ['RF', True, 0.89, 0.944, 14, -10],
#  ['KNN', True, 0.89, 0.952, 12, -12],
#  ['SVC', True, 0.89, 0.96, 10, -6],
#  ['LR', True, 0.89, 0.96, 10, -8],
#  ['DT', True, 0.9, 0.92, 20, -4],
#  ['RF', True, 0.9, 0.936, 16, -8],
#  ['KNN', True, 0.9, 0.952, 12, -12],
#  ['SVC', True, 0.9, 0.96, 10, -6],
#  ['LR', True, 0.9, 0.96, 10, -8],
#  ['DT', True, 0.91, 0.924, 19, -7],
#  ['RF', True, 0.91, 0.928, 18, -8],
#  ['KNN', True, 0.91, 0.952, 12, -12],
#  ['SVC', True, 0.91, 0.96, 10, -6],
#  ['LR', True, 0.91, 0.96, 10, -8],
#  ['DT', True, 0.92, 0.928, 18, -4],
#  ['RF', True, 0.92, 0.936, 16, -8],
#  ['KNN', True, 0.92, 0.952, 12, -12],
#  ['SVC', True, 0.92, 0.96, 10, -6],
#  ['LR', True, 0.92, 0.96, 10, -8],
#  ['DT', True, 0.93, 0.932, 17, -5],
#  ['RF', True, 0.93, 0.932, 17, -9],
#  ['KNN', True, 0.93, 0.952, 12, -12],
#  ['SVC', True, 0.93, 0.96, 10, -6],
#  ['LR', True, 0.93, 0.96, 10, -8],
#  ['DT', True, 0.94, 0.936, 16, -6],
#  ['RF', True, 0.94, 0.936, 16, -10],
#  ['KNN', True, 0.94, 0.952, 12, -12],
#  ['SVC', True, 0.94, 0.96, 10, -6],
#  ['LR', True, 0.94, 0.96, 10, -8],
#  ['DT', True, 0.95, 0.932, 17, -5],
#  ['RF', True, 0.95, 0.94, 15, -7],
#  ['KNN', True, 0.95, 0.952, 12, -12],
#  ['SVC', True, 0.95, 0.96, 10, -6],
#  ['LR', True, 0.95, 0.96, 10, -8],
#  ['DT', True, 0.96, 0.924, 19, -5],
#  ['RF', True, 0.96, 0.936, 16, -8],
#  ['KNN', True, 0.96, 0.952, 12, -12],
#  ['SVC', True, 0.96, 0.96, 10, -6],
#  ['LR', True, 0.96, 0.96, 10, -8],
#  ['DT', True, 0.97, 0.932, 17, -5],
#  ['RF', True, 0.97, 0.944, 14, -8],
#  ['KNN', True, 0.97, 0.952, 12, -12],
#  ['SVC', True, 0.97, 0.96, 10, -6],
#  ['LR', True, 0.97, 0.96, 10, -8],
#  ['DT', True, 0.98, 0.932, 17, -5],
#  ['RF', True, 0.98, 0.94, 15, -7],
#  ['KNN', True, 0.98, 0.952, 12, -12],
#  ['SVC', True, 0.98, 0.96, 10, -6],
#  ['LR', True, 0.98, 0.96, 10, -8],
#  ['DT', True, 0.99, 0.936, 16, -6],
#  ['RF', True, 0.99, 0.94, 15, -9],
#  ['KNN', True, 0.99, 0.952, 12, -12],
#  ['SVC', True, 0.99, 0.96, 10, -6],
#  ['LR', True, 0.99, 0.96, 10, -8]]

# %%
Weight = []
for i in range(10, 100):
    labelratio = 0.01 * i
    Weight += RunAllModels(bcw, labelratio, True)
Weight
# Out:
# [['DT', True, 0.1, 0.932, 17, -5],
#  ['RF', True, 0.1, 0.928, 18, -8],
#  ['KNN', True, 0.1, 0.952, 12, -12],
#  ['SVC', True, 0.1, 0.96, 10, -6],
#  ['LR', True, 0.1, 0.96, 10, -8],
#  ['DT', True, 0.11, 0.924, 19, -7],
#  ['RF', True, 0.11, 0.928, 18, -8],
#  ['KNN', True, 0.11, 0.952, 12, -12],
#  ['SVC', True, 0.11, 0.96, 10, -6],
#  ['LR', True, 0.11, 0.96, 10, -8],
#  ['DT', True, 0.12, 0.936, 16, -6],
#  ['RF', True, 0.12, 0.94, 15, -7],
#  ['KNN', True, 0.12, 0.952, 12, -12],
#  ['SVC', True, 0.12, 0.96, 10, -6],
#  ['LR', True, 0.12, 0.96, 10, -8],
#  ['DT', True, 0.13, 0.924, 19, -7],
#  ['RF', True, 0.13, 0.944, 14, -10],
#  ['KNN', True, 0.13, 0.952, 12, -12],
#  ['SVC', True, 0.13, 0.96, 10, -6],
#  ['LR', True, 0.13, 0.96, 10, -8],
#  ['DT', True, 0.14, 0.92, 20, -6],
#  ['RF', True, 0.14, 0.928, 18, -10],
#  ['KNN', True, 0.14, 0.952, 12, -12],
#  ['SVC', True, 0.14, 0.96, 10, -6],
#  ['LR', True, 0.14, 0.96, 10, -8],
#  ['DT', True, 0.15, 0.92, 20, -6],
#  ['RF', True, 0.15, 0.94, 15, -9],
#  ['KNN', True, 0.15, 0.952, 12, -12],
#  ['SVC', True, 0.15, 0.96, 10, -6],
#  ['LR', True, 0.15, 0.96, 10, -8],
#  ['DT', True, 0.16, 0.924, 19, -7],
#  ['RF', True, 0.16, 0.932, 17, -9],
#  ['KNN', True, 0.16, 0.952, 12, -12],
#  ['SVC', True, 0.16, 0.96, 10, -6],
#  ['LR', True, 0.16, 0.96, 10, -8],
#  ['DT', True, 0.17, 0.92, 20, -4],
#  ['RF', True, 0.17, 0.936, 16, -8],
#  ['KNN', True, 0.17, 0.952, 12, -12],
#  ['SVC', True, 0.17, 0.96, 10, -6],
#  ['LR', True, 0.17, 0.96, 10, -8],
#  ['DT', True, 0.18, 0.924, 19, -5],
#  ['RF', True, 0.18, 0.94, 15, -9],
#  ['KNN', True, 0.18, 0.952, 12, -12],
#  ['SVC', True, 0.18, 0.96, 10, -6],
#  ['LR', True, 0.18, 0.96, 10, -8],
#  ['DT', True, 0.19, 0.924, 19, -3],
#  ['RF', True, 0.19, 0.94, 15, -7],
#  ['KNN', True, 0.19, 0.952, 12, -12],
#  ['SVC', True, 0.19, 0.96, 10, -6],
#  ['LR', True, 0.19, 0.96, 10, -8],
#  ['DT', True, 0.2, 0.928, 18, -6],
#  ['RF', True, 0.2, 0.932, 17, -7],
#  ['KNN', True, 0.2, 0.952, 12, -12],
#  ['SVC', True, 0.2, 0.96, 10, -6],
#  ['LR', True, 0.2, 0.96, 10, -8],
#  ['DT', True, 0.21, 0.92, 20, -6],
#  ['RF', True, 0.21, 0.928, 18, -8],
#  ['KNN', True, 0.21, 0.952, 12, -12],
#  ['SVC', True, 0.21, 0.96, 10, -6],
#  ['LR', True, 0.21, 0.96, 10, -8],
#  ['DT', True, 0.22, 0.928, 18, -6],
#  ['RF', True, 0.22, 0.932, 17, -7],
#  ['KNN', True, 0.22, 0.952, 12, -12],
#  ['SVC', True, 0.22, 0.96, 10, -6],
#  ['LR', True, 0.22, 0.96, 10, -8],
#  ['DT', True, 0.23, 0.928, 18, -6],
#  ['RF', True, 0.23, 0.936, 16, -8],
#  ['KNN', True, 0.23, 0.952, 12, -12],
#  ['SVC', True, 0.23, 0.96, 10, -6],
#  ['LR', True, 0.23, 0.96, 10, -8],
#  ['DT', True, 0.24, 0.924, 19, -5],
#  ['RF', True, 0.24, 0.94, 15, -9],
#  ['KNN', True, 0.24, 0.952, 12, -12],
#  ['SVC', True, 0.24, 0.96, 10, -6],
#  ['LR', True, 0.24, 0.96, 10, -8],
#  ['DT', True, 0.25, 0.924, 19, -5],
#  ['RF', True, 0.25, 0.944, 14, -10],
#  ['KNN', True, 0.25, 0.952, 12, -12],
#  ['SVC', True, 0.25, 0.96, 10, -6],
#  ['LR', True, 0.25, 0.96, 10, -8],
#  ['DT', True, 0.26, 0.928, 18, -6],
#  ['RF', True, 0.26, 0.94, 15, -9],
#  ['KNN', True, 0.26, 0.952, 12, -12],
#  ['SVC', True, 0.26, 0.96, 10, -6],
#  ['LR', True, 0.26, 0.96, 10, -8],
#  ['DT', True, 0.27, 0.928, 18, -6],
#  ['RF', True, 0.27, 0.928, 18, -8],
#  ['KNN', True, 0.27, 0.952, 12, -12],
#  ['SVC', True, 0.27, 0.96, 10, -6],
#  ['LR', True, 0.27, 0.96, 10, -8],
#  ['DT', True, 0.28, 0.932, 17, -5],
#  ['RF', True, 0.28, 0.94, 15, -9],
#  ['KNN', True, 0.28, 0.952, 12, -12],
#  ['SVC', True, 0.28, 0.96, 10, -6],
#  ['LR', True, 0.28, 0.96, 10, -8],
#  ['DT', True, 0.29, 0.924, 19, -9],
#  ['RF', True, 0.29, 0.932, 17, -9],
#  ['KNN', True, 0.29, 0.952, 12, -12],
#  ['SVC', True, 0.29, 0.96, 10, -6],
#  ['LR', True, 0.29, 0.96, 10, -8],
#  ['DT', True, 0.3, 0.932, 17, -7],
#  ['RF', True, 0.3, 0.936, 16, -8],
#  ['KNN', True, 0.3, 0.952, 12, -12],
#  ['SVC', True, 0.3, 0.96, 10, -6],
#  ['LR', True, 0.3, 0.96, 10, -8],
#  ['DT', True, 0.31, 0.932, 17, -7],
#  ['RF', True, 0.31, 0.94, 15, -9],
#  ['KNN', True, 0.31, 0.952, 12, -12],
#  ['SVC', True, 0.31, 0.96, 10, -6],
#  ['LR', True, 0.31, 0.96, 10, -8],
#  ['DT', True, 0.32, 0.928, 18, -6],
#  ['RF', True, 0.32, 0.94, 15, -7],
#  ['KNN', True, 0.32, 0.952, 12, -12],
#  ['SVC', True, 0.32, 0.96, 10, -6],
#  ['LR', True, 0.32, 0.96, 10, -8],
#  ['DT', True, 0.33, 0.928, 18, -8],
#  ['RF', True, 0.33, 0.944, 14, -10],
#  ['KNN', True, 0.33, 0.952, 12, -12],
#  ['SVC', True, 0.33, 0.96, 10, -6],
#  ['LR', True, 0.33, 0.96, 10, -8],
#  ['DT', True, 0.34, 0.932, 17, -7],
#  ['RF', True, 0.34, 0.936, 16, -8],
#  ['KNN', True, 0.34, 0.952, 12, -12],
#  ['SVC', True, 0.34, 0.96, 10, -6],
#  ['LR', True, 0.34, 0.96, 10, -8],
#  ['DT', True, 0.35, 0.936, 16, -6],
#  ['RF', True, 0.35, 0.94, 15, -7],
#  ['KNN', True, 0.35, 0.952, 12, -12],
#  ['SVC', True, 0.35, 0.96, 10, -6],
#  ['LR', True, 0.35, 0.96, 10, -8],
#  ['DT', True, 0.36, 0.928, 18, -6],
#  ['RF', True, 0.36, 0.936, 16, -8],
#  ['KNN', True, 0.36, 0.952, 12, -12],
#  ['SVC', True, 0.36, 0.96, 10, -6],
#  ['LR', True, 0.36, 0.96, 10, -8],
#  ['DT', True, 0.37, 0.932, 17, -5],
#  ['RF', True, 0.37, 0.944, 14, -8],
#  ['KNN', True, 0.37, 0.952, 12, -12],
#  ['SVC', True, 0.37, 0.96, 10, -6],
#  ['LR', True, 0.37, 0.96, 10, -8],
#  ['DT', True, 0.38, 0.924, 19, -5],
#  ['RF', True, 0.38, 0.936, 16, -8],
#  ['KNN', True, 0.38, 0.952, 12, -12],
#  ['SVC', True, 0.38, 0.96, 10, -6],
#  ['LR', True, 0.38, 0.96, 10, -8],
#  ['DT', True, 0.39, 0.936, 16, -6],
#  ['RF', True, 0.39, 0.936, 16, -8],
#  ['KNN', True, 0.39, 0.952, 12, -12],
#  ['SVC', True, 0.39, 0.96, 10, -6],
#  ['LR', True, 0.39, 0.96, 10, -8],
#  ['DT', True, 0.4, 0.924, 19, -3],
#  ['RF', True, 0.4, 0.936, 16, -8],
#  ['KNN', True, 0.4, 0.952, 12, -12],
#  ['SVC', True, 0.4, 0.96, 10, -6],
#  ['LR', True, 0.4, 0.96, 10, -8],
#  ['DT', True, 0.41, 0.924, 19, -5],
#  ['RF', True, 0.41, 0.944, 14, -8],
#  ['KNN', True, 0.41, 0.952, 12, -12],
#  ['SVC', True, 0.41, 0.96, 10, -6],
#  ['LR', True, 0.41, 0.96, 10, -8],
#  ['DT', True, 0.42, 0.924, 19, -7],
#  ['RF', True, 0.42, 0.932, 17, -9],
#  ['KNN', True, 0.42, 0.952, 12, -12],
#  ['SVC', True, 0.42, 0.96, 10, -6],
#  ['LR', True, 0.42, 0.96, 10, -8],
#  ['DT', True, 0.43, 0.932, 17, -5],
#  ['RF', True, 0.43, 0.932, 17, -9],
#  ['KNN', True, 0.43, 0.952, 12, -12],
#  ['SVC', True, 0.43, 0.96, 10, -6],
#  ['LR', True, 0.43, 0.96, 10, -8],
#  ['DT', True, 0.44, 0.924, 19, -5],
#  ['RF', True, 0.44, 0.928, 18, -8],
#  ['KNN', True, 0.44, 0.952, 12, -12],
#  ['SVC', True, 0.44, 0.96, 10, -6],
#  ['LR', True, 0.44, 0.96, 10, -8],
#  ['DT', True, 0.45, 0.932, 17, -7],
#  ['RF', True, 0.45, 0.936, 16, -8],
#  ['KNN', True, 0.45, 0.952, 12, -12],
#  ['SVC', True, 0.45, 0.96, 10, -6],
#  ['LR', True, 0.45, 0.96, 10, -8],
#  ['DT', True, 0.46, 0.92, 20, -8],
#  ['RF', True, 0.46, 0.936, 16, -8],
#  ['KNN', True, 0.46, 0.952, 12, -12],
#  ['SVC', True, 0.46, 0.96, 10, -6],
#  ['LR', True, 0.46, 0.96, 10, -8],
#  ['DT', True, 0.47, 0.924, 19, -5],
#  ['RF', True, 0.47, 0.932, 17, -7],
#  ['KNN', True, 0.47, 0.952, 12, -12],
#  ['SVC', True, 0.47, 0.96, 10, -6],
#  ['LR', True, 0.47, 0.96, 10, -8],
#  ['DT', True, 0.48, 0.932, 17, -9],
#  ['RF', True, 0.48, 0.928, 18, -8],
#  ['KNN', True, 0.48, 0.952, 12, -12],
#  ['SVC', True, 0.48, 0.96, 10, -6],
#  ['LR', True, 0.48, 0.96, 10, -8],
#  ['DT', True, 0.49, 0.924, 19, -5],
#  ['RF', True, 0.49, 0.932, 17, -9],
#  ['KNN', True, 0.49, 0.952, 12, -12],
#  ['SVC', True, 0.49, 0.96, 10, -6],
#  ['LR', True, 0.49, 0.96, 10, -8],
#  ['DT', True, 0.5, 0.928, 18, -6],
#  ['RF', True, 0.5, 0.948, 13, -9],
#  ['KNN', True, 0.5, 0.952, 12, -12],
#  ['SVC', True, 0.5, 0.96, 10, -6],
#  ['LR', True, 0.5, 0.96, 10, -8],
#  ['DT', True, 0.51, 0.924, 19, -3],
#  ['RF', True, 0.51, 0.932, 17, -7],
#  ['KNN', True, 0.51, 0.952, 12, -12],
#  ['SVC', True, 0.51, 0.96, 10, -6],
#  ['LR', True, 0.51, 0.96, 10, -8],
#  ['DT', True, 0.52, 0.928, 18, -6],
#  ['RF', True, 0.52, 0.932, 17, -9],
#  ['KNN', True, 0.52, 0.952, 12, -12],
#  ['SVC', True, 0.52, 0.96, 10, -6],
#  ['LR', True, 0.52, 0.96, 10, -8],
#  ['DT', True, 0.53, 0.924, 19, -5],
#  ['RF', True, 0.53, 0.936, 16, -8],
#  ['KNN', True, 0.53, 0.952, 12, -12],
#  ['SVC', True, 0.53, 0.96, 10, -6],
#  ['LR', True, 0.53, 0.96, 10, -8],
#  ['DT', True, 0.54, 0.924, 19, -5],
#  ['RF', True, 0.54, 0.932, 17, -7],
#  ['KNN', True, 0.54, 0.952, 12, -12],
#  ['SVC', True, 0.54, 0.96, 10, -6],
#  ['LR', True, 0.54, 0.96, 10, -8],
#  ['DT', True, 0.55, 0.92, 20, -6],
#  ['RF', True, 0.55, 0.936, 16, -8],
#  ['KNN', True, 0.55, 0.952, 12, -12],
#  ['SVC', True, 0.55, 0.96, 10, -6],
#  ['LR', True, 0.55, 0.96, 10, -8],
#  ['DT', True, 0.56, 0.92, 20, -6],
#  ['RF', True, 0.56, 0.944, 14, -8],
#  ['KNN', True, 0.56, 0.952, 12, -12],
#  ['SVC', True, 0.56, 0.96, 10, -6],
#  ['LR', True, 0.56, 0.96, 10, -8],
#  ['DT', True, 0.57, 0.924, 19, -5],
#  ['RF', True, 0.57, 0.932, 17, -9],
#  ['KNN', True, 0.57, 0.952, 12, -12],
#  ['SVC', True, 0.57, 0.96, 10, -6],
#  ['LR', True, 0.57, 0.96, 10, -8],
#  ['DT', True, 0.58, 0.936, 16, -8],
#  ['RF', True, 0.58, 0.932, 17, -9],
#  ['KNN', True, 0.58, 0.952, 12, -12],
#  ['SVC', True, 0.58, 0.96, 10, -6],
#  ['LR', True, 0.58, 0.96, 10, -8],
#  ['DT', True, 0.59, 0.928, 18, -6],
#  ['RF', True, 0.59, 0.936, 16, -8],
#  ['KNN', True, 0.59, 0.952, 12, -12],
#  ['SVC', True, 0.59, 0.96, 10, -6],
#  ['LR', True, 0.59, 0.96, 10, -8],
#  ['DT', True, 0.6, 0.924, 19, -3],
#  ['RF', True, 0.6, 0.932, 17, -9],
#  ['KNN', True, 0.6, 0.952, 12, -12],
#  ['SVC', True, 0.6, 0.96, 10, -6],
#  ['LR', True, 0.6, 0.96, 10, -8],
#  ['DT', True, 0.61, 0.936, 16, -8],
#  ['RF', True, 0.61, 0.936, 16, -8],
#  ['KNN', True, 0.61, 0.952, 12, -12],
#  ['SVC', True, 0.61, 0.96, 10, -6],
#  ['LR', True, 0.61, 0.96, 10, -8],
#  ['DT', True, 0.62, 0.936, 16, -6],
#  ['RF', True, 0.62, 0.94, 15, -9],
#  ['KNN', True, 0.62, 0.952, 12, -12],
#  ['SVC', True, 0.62, 0.96, 10, -6],
#  ['LR', True, 0.62, 0.96, 10, -8],
#  ['DT', True, 0.63, 0.924, 19, -3],
#  ['RF', True, 0.63, 0.932, 17, -9],
#  ['KNN', True, 0.63, 0.952, 12, -12],
#  ['SVC', True, 0.63, 0.96, 10, -6],
#  ['LR', True, 0.63, 0.96, 10, -8],
#  ['DT', True, 0.64, 0.924, 19, -7],
#  ['RF', True, 0.64, 0.94, 15, -9],
#  ['KNN', True, 0.64, 0.952, 12, -12],
#  ['SVC', True, 0.64, 0.96, 10, -6],
#  ['LR', True, 0.64, 0.96, 10, -8],
#  ['DT', True, 0.65, 0.924, 19, -5],
#  ['RF', True, 0.65, 0.932, 17, -9],
#  ['KNN', True, 0.65, 0.952, 12, -12],
#  ['SVC', True, 0.65, 0.96, 10, -6],
#  ['LR', True, 0.65, 0.96, 10, -8],
#  ['DT', True, 0.66, 0.932, 17, -7],
#  ['RF', True, 0.66, 0.936, 16, -10],
#  ['KNN', True, 0.66, 0.952, 12, -12],
#  ['SVC', True, 0.66, 0.96, 10, -6],
#  ['LR', True, 0.66, 0.96, 10, -8],
#  ['DT', True, 0.67, 0.928, 18, -6],
#  ['RF', True, 0.67, 0.936, 16, -8],
#  ['KNN', True, 0.67, 0.952, 12, -12],
#  ['SVC', True, 0.67, 0.96, 10, -6],
#  ['LR', True, 0.67, 0.96, 10, -8],
#  ['DT', True, 0.68, 0.932, 17, -7],
#  ['RF', True, 0.68, 0.936, 16, -8],
#  ['KNN', True, 0.68, 0.952, 12, -12],
#  ['SVC', True, 0.68, 0.96, 10, -6],
#  ['LR', True, 0.68, 0.96, 10, -8],
#  ['DT', True, 0.69, 0.936, 16, -8],
#  ['RF', True, 0.69, 0.94, 15, -7],
#  ['KNN', True, 0.69, 0.952, 12, -12],
#  ['SVC', True, 0.69, 0.96, 10, -6],
#  ['LR', True, 0.69, 0.96, 10, -8],
#  ['DT', True, 0.7, 0.936, 16, -6],
#  ['RF', True, 0.7, 0.944, 14, -10],
#  ['KNN', True, 0.7, 0.952, 12, -12],
#  ['SVC', True, 0.7, 0.96, 10, -6],
#  ['LR', True, 0.7, 0.96, 10, -8],
#  ['DT', True, 0.71, 0.928, 18, -8],
#  ['RF', True, 0.71, 0.932, 17, -9],
#  ['KNN', True, 0.71, 0.952, 12, -12],
#  ['SVC', True, 0.71, 0.96, 10, -6],
#  ['LR', True, 0.71, 0.96, 10, -8],
#  ['DT', True, 0.72, 0.924, 19, -5],
#  ['RF', True, 0.72, 0.944, 14, -8],
#  ['KNN', True, 0.72, 0.952, 12, -12],
#  ['SVC', True, 0.72, 0.96, 10, -6],
#  ['LR', True, 0.72, 0.96, 10, -8],
#  ['DT', True, 0.73, 0.928, 18, -8],
#  ['RF', True, 0.73, 0.932, 17, -9],
#  ['KNN', True, 0.73, 0.952, 12, -12],
#  ['SVC', True, 0.73, 0.96, 10, -6],
#  ['LR', True, 0.73, 0.96, 10, -8],
#  ['DT', True, 0.74, 0.928, 18, -6],
#  ['RF', True, 0.74, 0.932, 17, -9],
#  ['KNN', True, 0.74, 0.952, 12, -12],
#  ['SVC', True, 0.74, 0.96, 10, -6],
#  ['LR', True, 0.74, 0.96, 10, -8],
#  ['DT', True, 0.75, 0.928, 18, -8],
#  ['RF', True, 0.75, 0.94, 15, -9],
#  ['KNN', True, 0.75, 0.952, 12, -12],
#  ['SVC', True, 0.75, 0.96, 10, -6],
#  ['LR', True, 0.75, 0.96, 10, -8],
#  ['DT', True, 0.76, 0.924, 19, -5],
#  ['RF', True, 0.76, 0.932, 17, -7],
#  ['KNN', True, 0.76, 0.952, 12, -12],
#  ['SVC', True, 0.76, 0.96, 10, -6],
#  ['LR', True, 0.76, 0.96, 10, -8],
#  ['DT', True, 0.77, 0.932, 17, -5],
#  ['RF', True, 0.77, 0.94, 15, -7],
#  ['KNN', True, 0.77, 0.952, 12, -12],
#  ['SVC', True, 0.77, 0.96, 10, -6],
#  ['LR', True, 0.77, 0.96, 10, -8],
#  ['DT', True, 0.78, 0.928, 18, -6],
#  ['RF', True, 0.78, 0.936, 16, -8],
#  ['KNN', True, 0.78, 0.952, 12, -12],
#  ['SVC', True, 0.78, 0.96, 10, -6],
#  ['LR', True, 0.78, 0.96, 10, -8],
#  ['DT', True, 0.79, 0.92, 20, -6],
#  ['RF', True, 0.79, 0.94, 15, -9],
#  ['KNN', True, 0.79, 0.952, 12, -12],
#  ['SVC', True, 0.79, 0.96, 10, -6],
#  ['LR', True, 0.79, 0.96, 10, -8],
#  ['DT', True, 0.8, 0.928, 18, -4],
#  ['RF', True, 0.8, 0.936, 16, -10],
#  ['KNN', True, 0.8, 0.952, 12, -12],
#  ['SVC', True, 0.8, 0.96, 10, -6],
#  ['LR', True, 0.8, 0.96, 10, -8],
#  ['DT', True, 0.81, 0.92, 20, -4],
#  ['RF', True, 0.81, 0.932, 17, -9],
#  ['KNN', True, 0.81, 0.952, 12, -12],
#  ['SVC', True, 0.81, 0.96, 10, -6],
#  ['LR', True, 0.81, 0.96, 10, -8],
#  ['DT', True, 0.82, 0.92, 20, -6],
#  ['RF', True, 0.82, 0.94, 15, -9],
#  ['KNN', True, 0.82, 0.952, 12, -12],
#  ['SVC', True, 0.82, 0.96, 10, -6],
#  ['LR', True, 0.82, 0.96, 10, -8],
#  ['DT', True, 0.83, 0.928, 18, -8],
#  ['RF', True, 0.83, 0.94, 15, -9],
#  ['KNN', True, 0.83, 0.952, 12, -12],
#  ['SVC', True, 0.83, 0.96, 10, -6],
#  ['LR', True, 0.83, 0.96, 10, -8],
#  ['DT', True, 0.84, 0.928, 18, -6],
#  ['RF', True, 0.84, 0.928, 18, -8],
#  ['KNN', True, 0.84, 0.952, 12, -12],
#  ['SVC', True, 0.84, 0.96, 10, -6],
#  ['LR', True, 0.84, 0.96, 10, -8],
#  ['DT', True, 0.85, 0.928, 18, -8],
#  ['RF', True, 0.85, 0.936, 16, -8],
#  ['KNN', True, 0.85, 0.952, 12, -12],
#  ['SVC', True, 0.85, 0.96, 10, -6],
#  ['LR', True, 0.85, 0.96, 10, -8],
#  ['DT', True, 0.86, 0.928, 18, -4],
#  ['RF', True, 0.86, 0.932, 17, -9],
#  ['KNN', True, 0.86, 0.952, 12, -12],
#  ['SVC', True, 0.86, 0.96, 10, -6],
#  ['LR', True, 0.86, 0.96, 10, -8],
#  ['DT', True, 0.87, 0.928, 18, -6],
#  ['RF', True, 0.87, 0.944, 14, -10],
#  ['KNN', True, 0.87, 0.952, 12, -12],
#  ['SVC', True, 0.87, 0.96, 10, -6],
#  ['LR', True, 0.87, 0.96, 10, -8],
#  ['DT', True, 0.88, 0.936, 16, -6],
#  ['RF', True, 0.88, 0.94, 15, -9],
#  ['KNN', True, 0.88, 0.952, 12, -12],
#  ['SVC', True, 0.88, 0.96, 10, -6],
#  ['LR', True, 0.88, 0.96, 10, -8],
#  ['DT', True, 0.89, 0.932, 17, -7],
#  ['RF', True, 0.89, 0.94, 15, -11],
#  ['KNN', True, 0.89, 0.952, 12, -12],
#  ['SVC', True, 0.89, 0.96, 10, -6],
#  ['LR', True, 0.89, 0.96, 10, -8],
#  ['DT', True, 0.9, 0.932, 17, -7],
#  ['RF', True, 0.9, 0.94, 15, -9],
#  ['KNN', True, 0.9, 0.952, 12, -12],
#  ['SVC', True, 0.9, 0.96, 10, -6],
#  ['LR', True, 0.9, 0.96, 10, -8],
#  ['DT', True, 0.91, 0.928, 18, -6],
#  ['RF', True, 0.91, 0.932, 17, -9],
#  ['KNN', True, 0.91, 0.952, 12, -12],
#  ['SVC', True, 0.91, 0.96, 10, -6],
#  ['LR', True, 0.91, 0.96, 10, -8],
#  ['DT', True, 0.92, 0.928, 18, -6],
#  ['RF', True, 0.92, 0.936, 16, -8],
#  ['KNN', True, 0.92, 0.952, 12, -12],
#  ['SVC', True, 0.92, 0.96, 10, -6],
#  ['LR', True, 0.92, 0.96, 10, -8],
#  ['DT', True, 0.93, 0.924, 19, -7],
#  ['RF', True, 0.93, 0.932, 17, -9],
#  ['KNN', True, 0.93, 0.952, 12, -12],
#  ['SVC', True, 0.93, 0.96, 10, -6],
#  ['LR', True, 0.93, 0.96, 10, -8],
#  ['DT', True, 0.94, 0.932, 17, -5],
#  ['RF', True, 0.94, 0.94, 15, -9],
#  ['KNN', True, 0.94, 0.952, 12, -12],
#  ['SVC', True, 0.94, 0.96, 10, -6],
#  ['LR', True, 0.94, 0.96, 10, -8],
#  ['DT', True, 0.95, 0.932, 17, -5],
#  ['RF', True, 0.95, 0.936, 16, -10],
#  ['KNN', True, 0.95, 0.952, 12, -12],
#  ['SVC', True, 0.95, 0.96, 10, -6],
#  ['LR', True, 0.95, 0.96, 10, -8],
#  ['DT', True, 0.96, 0.932, 17, -5],
#  ['RF', True, 0.96, 0.936, 16, -8],
#  ['KNN', True, 0.96, 0.952, 12, -12],
#  ['SVC', True, 0.96, 0.96, 10, -6],
#  ['LR', True, 0.96, 0.96, 10, -8],
#  ['DT', True, 0.97, 0.932, 17, -5],
#  ['RF', True, 0.97, 0.944, 14, -10],
#  ['KNN', True, 0.97, 0.952, 12, -12],
#  ['SVC', True, 0.97, 0.96, 10, -6],
#  ['LR', True, 0.97, 0.96, 10, -8],
#  ['DT', True, 0.98, 0.924, 19, -7],
#  ['RF', True, 0.98, 0.94, 15, -5],
#  ['KNN', True, 0.98, 0.952, 12, -12],
#  ['SVC', True, 0.98, 0.96, 10, -6],
#  ['LR', True, 0.98, 0.96, 10, -8],
#  ['DT', True, 0.99, 0.932, 17, -7],
#  ['RF', True, 0.99, 0.928, 18, -8],
#  ['KNN', True, 0.99, 0.952, 12, -12],
#  ['SVC', True, 0.99, 0.96, 10, -6],
#  ['LR', True, 0.99, 0.96, 10, -8]]

# %% [markdown]
# # 5. Get Some important statistics for variosu labelratio and models with groupby and other statistics

# %%
DefaultDF = pd.DataFrame(Default, columns = ['Model', 'Weight', 'LabelRatio', 'Accuracy', 'N_errors', 'Bias'])
WeightDF = pd.DataFrame(Weight, columns = ['Model', 'Weight', 'LabelRatio', 'Accuracy', 'N_errors', 'Bias'])

# %%
print('DefaultDF: ' + str(DefaultDF.Bias.sum()))
print('WeightDF:  ' + str(WeightDF.Bias.sum()))
# Out:
# DefaultDF: -3596
# WeightDF:  -3638

# %%
DefaultDF.describe()
# Out:
#        LabelRatio    Accuracy    N_errors        Bias
# count  450.000000  450.000000  450.000000  450.000000
# mean     0.545000    0.947396   13.151111   -7.991111
# std      0.260081    0.013138    3.284479    2.389642
# min      0.100000    0.920000   10.000000  -12.000000
# 25%      0.320000    0.936000   10.000000   -9.000000
# 50%      0.545000    0.952000   12.000000   -8.000000
# 75%      0.770000    0.960000   16.000000   -6.000000
# max      0.990000    0.960000   20.000000   -3.000000

# %%
WeightDF.describe()
# Out:
#        LabelRatio    Accuracy    N_errors        Bias
# count  450.000000  450.000000  450.000000  450.000000
# mean     0.545000    0.947147   13.213333   -8.084444
# std      0.260081    0.013454    3.363475    2.328669
# min      0.100000    0.920000   10.000000  -12.000000
# 25%      0.320000    0.932000   10.000000   -9.000000
# 50%      0.545000    0.952000   12.000000   -8.000000
# 75%      0.770000    0.960000   17.000000   -6.000000
# max      0.990000    0.960000   20.000000   -3.000000

# %%
DefaultDF[DefaultDF.LabelRatio > 0.7].describe()
# Out:
#        LabelRatio    Accuracy    N_errors        Bias
# count  145.000000  145.000000  145.000000  145.000000
# mean     0.850000    0.947531   13.117241   -7.972414
# std      0.083956    0.012983    3.245731    2.394858
# min      0.710000    0.920000   10.000000  -12.000000
# 25%      0.780000    0.936000   10.000000   -9.000000
# 50%      0.850000    0.952000   12.000000   -8.000000
# 75%      0.920000    0.960000   16.000000   -6.000000
# max      0.990000    0.960000   20.000000   -4.000000

# %%
WeightDF[WeightDF.LabelRatio > 0.7].describe()
# Out:
#        LabelRatio    Accuracy    N_errors        Bias
# count  145.000000  145.000000  145.000000  145.000000
# mean     0.850000    0.947310   13.172414   -8.151724
# std      0.083956    0.013227    3.306863    2.325376
# min      0.710000    0.920000   10.000000  -12.000000
# 25%      0.780000    0.932000   10.000000   -9.000000
# 50%      0.850000    0.952000   12.000000   -8.000000
# 75%      0.920000    0.960000   17.000000   -6.000000
# max      0.990000    0.960000   20.000000   -4.000000

# %%
DefaultDF[(DefaultDF.LabelRatio < 0.7) & (DefaultDF.LabelRatio > 0.2)].describe()
# Out:
#        LabelRatio    Accuracy    N_errors        Bias
# count  245.000000  245.000000  245.000000  245.000000
# mean     0.450000    0.947478   13.130612   -7.987755
# std      0.141711    0.013062    3.265455    2.411519
# min      0.210000    0.920000   10.000000  -12.000000
# 25%      0.330000    0.936000   10.000000   -9.000000
# 50%      0.450000    0.952000   12.000000   -8.000000
# 75%      0.570000    0.960000   16.000000   -6.000000
# max      0.690000    0.960000   20.000000   -3.000000

# %%
WeightDF[(WeightDF.LabelRatio < 0.7) & (WeightDF.LabelRatio > 0.2)].describe()
# Out:
#        LabelRatio    Accuracy    N_errors        Bias
# count  245.000000  245.000000  245.000000  245.000000
# mean     0.450000    0.947135   13.216327   -8.057143
# std      0.141711    0.013457    3.364189    2.321673
# min      0.210000    0.920000   10.000000  -12.000000
# 25%      0.330000    0.936000   10.000000   -9.000000
# 50%      0.450000    0.952000   12.000000   -8.000000
# 75%      0.570000    0.960000   16.000000   -6.000000
# max      0.690000    0.960000   20.000000   -3.000000

# %%
DefaultDF.groupby('Model').sum()
# Out:
#        Weight  LabelRatio  Accuracy  N_errors  Bias
# Model
# DT         90       49.05    83.564      1609  -509
# KNN        90       49.05    85.680      1080 -1080
# LR         90       49.05    86.400       900  -720
# RF         90       49.05    84.284      1429  -747
# SVC        90       49.05    86.400       900  -540

# %%
WeightDF.groupby('Model').sum()
# Out:
#        Weight  LabelRatio  Accuracy  N_errors  Bias
# Model
# DT         90       49.05    83.480      1630  -536
# KNN        90       49.05    85.680      1080 -1080
# LR         90       49.05    86.400       900  -720
# RF         90       49.05    84.256      1436  -762
# SVC        90       49.05    86.400       900  -540

# %%
DefaultDF[DefaultDF.LabelRatio > 0.7].groupby('Model').sum()
# Out:
#        Weight  LabelRatio  Accuracy  N_errors  Bias
# Model
# DT         29       24.65    26.940       515  -157
# KNN        29       24.65    27.608       348  -348
# LR         29       24.65    27.840       290  -232
# RF         29       24.65    27.164       459  -245
# SVC        29       24.65    27.840       290  -174

# %%
WeightDF[WeightDF.LabelRatio > 0.7].groupby('Model').sum()
# Out:
#        Weight  LabelRatio  Accuracy  N_errors  Bias
# Model
# DT         29       24.65    26.912       522  -176
# KNN        29       24.65    27.608       348  -348
# LR         29       24.65    27.840       290  -232
# RF         29       24.65    27.160       460  -252
# SVC        29       24.65    27.840       290  -174
